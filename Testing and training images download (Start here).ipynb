# %% [markdown]
# ## downloading the data with certain labels

# %% [markdown]
# ### Data for training

# %%
import csv 
import pandas as pd
df = pd.read_csv('oidv6-train-annotations-bbox.csv')

# %%
df.head()

# %%
rows = df['LabelName'] == '/m/01yrx'
df2 = df[rows]
df2.head(20)
# Out:
#                 ImageID  Source LabelName  Confidence      XMin      XMax  \
# 1709   0000de486dc6c49f  xclick  /m/01yrx           1  0.019608  0.998366
# 7930   00056e547b7c00d6  xclick  /m/01yrx           1  0.003125  0.999375
# 9109   00067fe83e3e21c8  xclick  /m/01yrx           1  0.156250  0.691875
# 11627  0008ab3d8674f6ca  xclick  /m/01yrx           1  0.099167  0.713333
# 13871  000aa552a9d80891  xclick  /m/01yrx           1  0.000000  0.772500
# 15277  000bd897ca7df023  xclick  /m/01yrx           1  0.168125  0.435000
# 15657  000c24660cd3fd95  xclick  /m/01yrx           1  0.089000  0.914000
# 21133  001175fd73c3039b  xclick  /m/01yrx           1  0.000000  0.639535
# 22189  00129ccb99612727  xclick  /m/01yrx           1  0.009375  0.999219
# 23236  0013eebbcafa70e5  xclick  /m/01yrx           1  0.281875  0.746875
# 23360  00142fa70fe03ffa  xclick  /m/01yrx           1  0.000000  0.999231
# 23984  0014bd425c9a203e  xclick  /m/01yrx           1  0.080000  0.997500
# 27853  0018e9995b29da7a  xclick  /m/01yrx           1  0.000000  0.999317
# 28234  0019757ca6f64107  xclick  /m/01yrx           1  0.000000  0.879375
# 28608  0019edb653711193  xclick  /m/01yrx           1  0.161250  0.784375
# 29370  001adacc7f6ddca5  xclick  /m/01yrx           1  0.003752  0.985929
# 29788  001b61e5094d71cb  xclick  /m/01yrx           1  0.313333  0.789167
# 32649  001f2bec02f16977  xclick  /m/01yrx           1  0.176875  0.455000
# 32650  001f2bec02f16977  xclick  /m/01yrx           1  0.638750  0.761875
# 34091  00218e254b8a046b  xclick  /m/01yrx           1  0.000000  0.600625
#
#            YMin      YMax  IsOccluded  IsTruncated  ...  IsDepiction  \
# 1709   0.024510  0.977124           1            1  ...            0
# 7930   0.007500  0.999167           0            1  ...            0
# 9109   0.000000  0.983067           1            0  ...            0
# 11627  0.396875  0.706250           0            0  ...            0
# 13871  0.000000  0.998889           0            1  ...            0
# 15277  0.223265  0.815197           0            0  ...            1
# 15657  0.098000  0.911000           0            1  ...            1
# 21133  0.005168  0.981912           0            1  ...            0
# 22189  0.052083  0.816667           0            1  ...            0
# 23236  0.215833  0.856667           0            0  ...            0
# 23360  0.000000  0.999071           0            1  ...            0
# 23984  0.000000  0.996255           0            1  ...            0
# 27853  0.000000  0.998975           0            1  ...            0
# 28234  0.132500  0.790000           1            0  ...            0
# 28608  0.207778  0.842222           0            0  ...            0
# 29370  0.439375  0.999375           0            1  ...            0
# 29788  0.511250  0.767500           0            0  ...            0
# 32649  0.348333  0.727500           0            1  ...            1
# 32650  0.322500  0.703333           0            0  ...            1
# 34091  0.000000  0.290712           1            1  ...            0
#
#        IsInside  XClick1X  XClick2X  XClick3X  XClick4X  XClick1Y  XClick2Y  \
# 1709          0  0.617647  0.998366  0.133987  0.019608  0.024510  0.449346
# 7930          0  0.173125  0.003125  0.340625  0.999375  0.007500  0.548333
# 9109          0  0.363750  0.156250  0.691875  0.661250  0.000000  0.165569
# 11627         0  0.465833  0.713333  0.590833  0.099167  0.396875  0.543125
# 13871         0  0.772500  0.527500  0.000000  0.244375  0.682222  0.000000
# 15277         0  0.296875  0.168125  0.262500  0.435000  0.223265  0.273921
# 15657         0  0.914000  0.595000  0.635000  0.089000  0.852000  0.911000
# 21133         0  0.467054  0.639535  0.000000  0.000000  0.005168  0.630491
# 22189         0  0.482812  0.999219  0.450781  0.009375  0.052083  0.357292
# 23236         0  0.732500  0.746875  0.484375  0.281875  0.215833  0.250000
# 23360         0  0.999231  0.440000  0.000000  0.500769  0.743494  0.999071
# 23984         0  0.475000  0.997500  0.860000  0.080000  0.000000  0.775281
# 27853         0  0.413934  0.000000  0.429645  0.999317  0.000000  0.345287
# 28234         0  0.858750  0.879375  0.817500  0.000000  0.132500  0.416667
# 28608         0  0.681875  0.784375  0.280000  0.161250  0.207778  0.537778
# 29370         0  0.985929  0.003752  0.552533  0.343340  0.633750  0.577500
# 29788         0  0.313333  0.494167  0.789167  0.637500  0.705000  0.511250
# 32649         0  0.370625  0.262500  0.176875  0.455000  0.348333  0.727500
# 32650         0  0.718750  0.761875  0.638750  0.660625  0.322500  0.391667
# 34091         0  0.158750  0.600625  0.066250  0.000000  0.000000  0.000000
#
#        XClick3Y  XClick4Y
# 1709   0.977124  0.446078
# 7930   0.999167  0.631667
# 9109   0.935089  0.983067
# 11627  0.706250  0.466875
# 13871  0.404444  0.998889
# 15277  0.815197  0.447467
# 15657  0.098000  0.531000
# 21133  0.981912  0.379845
# 22189  0.816667  0.493750
# 23236  0.856667  0.685833
# 23360  0.723048  0.000000
# 23984  0.996255  0.970037
# 27853  0.998975  0.599385
# 28234  0.790000  0.530000
# 28608  0.842222  0.393333
# 29370  0.439375  0.999375
# 29788  0.663750  0.767500
# 32649  0.611667  0.527500
# 32650  0.542500  0.703333
# 34091  0.290712  0.179735
#
# [20 rows x 21 columns]

# %%
##I changed this to 10 was 1000
imageids = []
df_id = df2.iloc[:1000,0]
for id in df_id:
    imageids.append(id)
#for in range(10):
 #   imageids = df

# %%
df_annotation = df2.iloc[0:1000,0:8]
df_annotation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1709 to 614399
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ImageID    1000 non-null   object
#  1   Source     1000 non-null   object
#  2   LabelName  1000 non-null   object
#  3   XMin       1000 non-null   float64
#  4   XMax       1000 non-null   float64
#  5   YMin       1000 non-null   float64
#  6   YMax       1000 non-null   float64
# dtypes: float64(4), object(3)
# memory usage: 62.5+ KB

# %%
df_for_tensor = df_annotation.loc[:,['ImageID','XMin','YMin','XMax','YMax']]
df_for_tensor.shape
# Out:
# (1000, 4)

# %%
## Save the changes as a csv file.
df_for_tensor_test.to_csv('boxes.csv',index=False)

# %% [markdown]
# ### Script to download the photos

# %%
import fiftyone
dataset = fiftyone.zoo.load_zoo_dataset(
              "open-images-v6",
              split="train",
              label_types=["detections"],
              classes=["Cat"],
              max_samples=1000,
              image_ids = imageids
          )

# %%
print(dataset)

# %%
session = fiftyone.launch_app(dataset)

# %% [markdown]
# ## Data for testing

# %%
import csv 
import pandas as pd
df_test = pd.read_csv('test-annotations-bbox.csv')

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 937327 entries, 0 to 937326
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   ImageID      937327 non-null  object
#  1   Source       937327 non-null  object
#  2   LabelName    937327 non-null  object
#  3   Confidence   937327 non-null  int64
#  4   XMin         937327 non-null  float64
#  5   XMax         937327 non-null  float64
#  6   YMin         937327 non-null  float64
#  7   YMax         937327 non-null  float64
#  8   IsOccluded   937327 non-null  int64
#  9   IsTruncated  937327 non-null  int64
#  10  IsGroupOf    937327 non-null  int64
#  11  IsDepiction  937327 non-null  int64
#  12  IsInside     937327 non-null  int64
# dtypes: float64(4), int64(6), object(3)
# memory usage: 93.0+ MB

# %%
rows = df_test['LabelName'] == '/m/01yrx'
df2_test = df_test[rows]
df2_test.head(20)
# Out:
#                 ImageID  Source LabelName  Confidence      XMin      XMax  \
# 1728   00567dcce4a5f7d9  xclick  /m/01yrx           1  0.070312  1.000000
# 3346   00b6be538644be0b  xclick  /m/01yrx           1  0.000000  0.839583
# 3720   00d9419e2faa59fa  xclick  /m/01yrx           1  0.055957  0.853791
# 3783   00dd6d717c50e78b  xclick  /m/01yrx           1  0.000000  0.349206
# 3784   00dd6d717c50e78b  xclick  /m/01yrx           1  0.320988  0.723104
# 3785   00dd6d717c50e78b  xclick  /m/01yrx           1  0.670194  1.000000
# 5052   012b40f0d9ccba39  xclick  /m/01yrx           1  0.141593  1.000000
# 6629   017c776a67956dd9  xclick  /m/01yrx           1  0.261062  0.989676
# 6686   018376cd9ec14643  xclick  /m/01yrx           1  0.000000  0.700775
# 7114   01a471db31e88727  xclick  /m/01yrx           1  0.176563  0.778125
# 7557   01cc07838fc28a68  xclick  /m/01yrx           1  0.000000  1.000000
# 7849   01e368998a68ff28  xclick  /m/01yrx           1  0.206504  0.967480
# 7926   01e836367cfb0c76  xclick  /m/01yrx           1  0.000000  0.953125
# 8489   020418f41a5dde99  xclick  /m/01yrx           1  0.025074  1.000000
# 9060   022d642a36f4a551  xclick  /m/01yrx           1  0.170833  0.872917
# 9671   02530be4f2f64f16  xclick  /m/01yrx           1  0.056667  0.936667
# 11958  02e94b92d16c65de  xclick  /m/01yrx           1  0.241176  0.855882
# 12234  02fbcf6ff524762f  xclick  /m/01yrx           1  0.036284  0.367199
# 12235  02fbcf6ff524762f  xclick  /m/01yrx           1  0.435414  0.959361
# 12236  02fbcf6ff524762f  xclick  /m/01yrx           1  0.507983  0.856313
#
#            YMin      YMax  IsOccluded  IsTruncated  IsGroupOf  IsDepiction  \
# 1728   0.050000  0.739583           0            1          0            0
# 3346   0.023438  1.000000           0            1          0            0
# 3720   0.001805  1.000000           1            0          0            0
# 3783   0.000000  0.560847           0            1          0            0
# 3784   0.000000  0.735450           0            0          0            0
# 3785   0.333333  0.878307           0            1          0            0
# 5052   0.000000  0.951327           0            1          0            0
# 6629   0.192478  1.000000           0            1          0            0
# 6686   0.039916  1.000000           0            1          0            0
# 7114   0.097917  1.000000           0            0          0            0
# 7557   0.089970  1.000000           0            0          0            0
# 7849   0.126252  0.951904           0            0          0            0
# 7926   0.000000  1.000000           0            1          0            0
# 8489   0.000000  1.000000           0            1          0            0
# 9060   0.100000  0.946875           0            0          0            0
# 9671   0.049808  0.973180           0            0          0            0
# 11958  0.000000  0.829268           0            1          0            0
# 12234  0.208989  0.932584           0            0          0            1
# 12235  0.640449  0.921348           0            0          0            1
# 12236  0.069663  0.458427           0            0          0            1
#
#        IsInside
# 1728          0
# 3346          0
# 3720          0
# 3783          0
# 3784          0
# 3785          0
# 5052          0
# 6629          0
# 6686          0
# 7114          0
# 7557          0
# 7849          0
# 7926          0
# 8489          0
# 9060          0
# 9671          0
# 11958         0
# 12234         0
# 12235         0
# 12236         0

# %%
df2_test.info()

# %%
imageids_test = []
df_id_test = df2_test.iloc[:1000,0]
for id in df_id_test:
    imageids_test.append(id)

# %%
df_annotation_test = df2_test.iloc[0:1000,0:8]
df_annotation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1728 to 818332
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ImageID    1000 non-null   object
#  1   Source     1000 non-null   object
#  2   LabelName  1000 non-null   object
#  3   XMin       1000 non-null   float64
#  4   XMax       1000 non-null   float64
#  5   YMin       1000 non-null   float64
#  6   YMax       1000 non-null   float64
# dtypes: float64(4), object(3)
# memory usage: 62.5+ KB

# %%
df_for_tensor_test = df_annotation.loc[:,['ImageID','XMin','YMin','XMax','YMax']]
# Out:
# (1000, 5)

# %%
df_for_tensor_test.to_csv('Boxes_test.csv',index=False)

# %% [markdown]
# ### Download the testing photos

# %%
import fiftyone
dataset = fiftyone.zoo.load_zoo_dataset(
              "open-images-v6",
              split="test",
              label_types=["detections"],
              classes=["Cat"],
              max_samples=1000,
              image_ids = imageids
          )

# %%
print(dataset)

# %%
session = fiftyone.launch_app(dataset)
